# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset_c, train_labels_c = reformat(train_dataset, train_labels)
valid_dataset_c, valid_labels_c = reformat(valid_dataset, valid_labels)
test_dataset_c, test_labels_c = reformat(test_dataset, test_labels)
print('Training set', train_dataset_c.shape, train_labels_c.shape)
print('Validation set', valid_dataset_c.shape, valid_labels_c.shape)
print('Test set', test_dataset_c.shape, test_labels_c.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 200
num_hidden = 200
# neural network structure for this sample:
#
# · · · · · · · · · ·    (input data, 1-deep)                 X [batch, 28, 28, 1]
# @ @ @ @ @ @ @ @ @ @ -- conv. layer 6x6x1=>6 stride 1        W1 [6, 6, 1, 6]        B1 [6]
# ∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶                                         Y1 [batch, 28, 28, 6]
#   @ @ @ @ @ @ @ @   -- conv. layer 5x5x6=>12 stride 2       W2 [5, 5, 6, 12]        B2 [12]
#   ∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶                                           Y2 [batch, 14, 14, 12]
#     @ @ @ @ @ @     -- conv. layer 4x4x12=>24 stride 2      W3 [4, 4, 12, 24]       B3 [24]
#     ∶∶∶∶∶∶∶∶∶∶∶                                             Y3 [batch, 7, 7, 24] => reshaped to YY [batch, 7*7*24]
#      \x/x\x\x/ ✞    -- fully connected layer (relu+dropout) W4 [7*7*24, 200]       B4 [200]
#       · · · ·                                               Y4 [batch, 200]
#       \x/x\x/       -- fully connected layer (softmax)      W5 [200, 10]           B5 [10]
#        · · ·                                                Y [batch, 20]

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset_c)
  tf_test_dataset = tf.constant(test_dataset_c)
  
  #Variables.
  # variable learning rate
  lr = tf.placeholder(tf.float32)
  # pkeep for dropout
  pkeep = tf.placeholder(tf.float32)
  # three convolutional layers with their channel counts, and a
  # fully connected layer (tha last layer has 10 softmax neurons)
  L1 = 6  # first convolutional layer output depth
  L2 = 12  # second convolutional layer output depth
  L3 = 24  # third convolutional layer
  L4 = 200  # fully connected layer

  W1 = tf.Variable(tf.truncated_normal([6, 6, 1, L1], stddev=np.sqrt(2/28*28)))  # 6x6 patch, 1 input channel, L1 output channels
  B1 = tf.Variable(tf.constant(0.1, tf.float32, [L1]))
  W2 = tf.Variable(tf.truncated_normal([5, 5, L1, L2], stddev=0.1))
  B2 = tf.Variable(tf.constant(0.1, tf.float32, [L2]))
  W3 = tf.Variable(tf.truncated_normal([4, 4, L2, L3], stddev=0.1))
  B3 = tf.Variable(tf.constant(0.1, tf.float32, [L3]))

  W4 = tf.Variable(tf.truncated_normal([7 * 7 * L3, L4], stddev=0.1))
  B4 = tf.Variable(tf.constant(0.1, tf.float32, [L4]))
  W5 = tf.Variable(tf.truncated_normal([L4, 10], stddev=0.1))
  B5 = tf.Variable(tf.constant(0.1, tf.float32, [10]))

  # Model.
  def model(data, dropout=True):
    if dropout:
        stride = 1  # output is 28x28
        Y1 = tf.nn.relu(tf.nn.conv2d(data, W1, strides=[1, stride, stride, 1], padding='SAME') + B1)
        stride = 2  # output is 14x14
        Y2 = tf.nn.relu(tf.nn.conv2d(Y1, W2, strides=[1, stride, stride, 1], padding='SAME') + B2)
        stride = 2  # output is 7x7
        Y3 = tf.nn.relu(tf.nn.conv2d(Y2, W3, strides=[1, stride, stride, 1], padding='SAME') + B3)

        # reshape the output from the third convolution for the fully connected layer
        YY = tf.reshape(Y3, shape=[-1, 7 * 7 * L3])

        Y4 = tf.nn.relu(tf.matmul(YY, W4) + B4)
        Y4d = tf.nn.dropout(Y4, pkeep)

        return tf.matmul(Y4d, W5) + B5
    if not dropout:
        stride = 1  # output is 28x28
        Y1 = tf.nn.relu(tf.nn.conv2d(data, W1, strides=[1, stride, stride, 1], padding='SAME') + B1)
        stride = 2  # output is 14x14
        Y2 = tf.nn.relu(tf.nn.conv2d(Y1, W2, strides=[1, stride, stride, 1], padding='SAME') + B2)
        stride = 2  # output is 7x7
        Y3 = tf.nn.relu(tf.nn.conv2d(Y2, W3, strides=[1, stride, stride, 1], padding='SAME') + B3)

        # reshape the output from the third convolution for the fully connected layer
        YY = tf.reshape(Y3, shape=[-1, 7 * 7 * L3])

        Y4 = tf.nn.relu(tf.matmul(YY, W4) + B4)
        Y4d = tf.nn.dropout(Y4, pkeep)
        return tf.matmul(Y4, W5) + B5

 
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  batch = tf.Variable(0, trainable=False)
  train_size = train_labels.shape[0]
  learning_rate = tf.train.exponential_decay(0.1, 
                                               batch, 
                                               train_size,
                                               0.01,
                                               staircase = True)

  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=batch)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, False))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels_c.shape[0] - batch_size)
    batch_data = train_dataset_c[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels_c[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, pkeep : 0.5}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels_c))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels_c))

# original = 89.1%
# with biases set to 0.1 or num of entry points / 10 = 90.2%
#  learning_rate = tf.train.exponential_decay(lr start = 0.099 and step decay 0.0001 = 90.7%
# batch_size = 300 91.9%
# bs = 200, ps = 6, depth = 24, num_hidden = 64, dropout = 0.9  - accuracy = 92.3% 
# bs = 200, ps = 6, depth = 32, num_hidden = 100, dropout = 0.9  - accuracy = 92.9% 
# bs = 200, ps = 6, depth = 32, num_hidden = 200, dropout = 0.5  - accuracy = 92.9% 
# bs = 200, ps = 6, depth = 48, num_hidden = 100, dropout = 0.9  - accuracy = 93.1% 
# bs = 200, ps = 6, depth = 64, num_hidden = 200, dropout = 0.9  - accuracy = 93.4% 
# bs = 300, ps = 6, depth = 64, num_hidden = 200, dropout = 0.9  - accuracy = 93% 
# bs = 200, ps = 5, depth = 64, num_hidden = 200, dropout = 0.9  - accuracy = 93.3% 
# bs = 200, ps = 5, depth = 32, num_hidden = 200, dropout = 0.9  - accuracy = 93.7% 
# bs = 200, ps = 6, depth = 44, num_hidden = 200, dropout = 0.9  - accuracy = 93% 
# bs = 200, ps = 6, depth = 44, num_hidden = 32, dropout = 0.9  - accuracy = 91.8% 
# bs = 200, ps = 5, depth = 32, num_hidden = 600, dropout = 0.9  - accuracy = 93.7%
# bs = 200, ps = 5, depth = 32, num_hidden = 800, dropout = 0.9  - accuracy = 93.6%
# bs = 200, ps = 5, depth = 32, num_hidden = 200, dropout = 0.75  - accuracy = 92.8%
# bs = 200, ps = 5, depth = 32, num_hidden = 200, dropout = 0.5  - accuracy = 92.6%
# new architecture
# L1, L2, L3, L4 = 6, 12, 24, 200, bs = 200, lr decay = 0.099, 0.0001, steps = 3001 = 94.6%
# L1, L2, L3, L4 = 6, 12, 24, 200, bs = 200, lr decay = 0.1, 0.01, steps = 3001 = 94.9%
# L1, L2, L3, L4 = 6, 12, 24, 200, bs = 200, lr decay = 0.2, 0.01, steps = 1001 = 93.6%
# L1, L2, L3, L4 = 6, 12, 24, 200, bs = 200, lr decay = 0.2, 0.01, steps = 3001 = 93.7%
# L1, L2, L3, L4 = 6, 12, 24, 200, bs = 200, lr decay = 0.09, 0.01, steps = 3001 = 94.4%
# Out:
# Initialized
# Minibatch loss at step 0: 3.652546
# Minibatch accuracy: 7.0%
# Validation accuracy: 9.1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-5ee9549929eb> in <module>()
#      10     feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, pkeep : 0.5}
#      11     _, l, predictions = session.run(
# ---> 12       [optimizer, loss, train_prediction], feed_dict=feed_dict)
#      13     if (step % 50 == 0):
#      14       print('Minibatch loss at step %d: %f' % (step, l))
#
# /home/yol/miniconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/yol/miniconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /home/yol/miniconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/yol/miniconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /home/yol/miniconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 128
num_hidden = 200
image_size = 28
num_channels = 1
# neural network structure for this sample:
#
# · · · · · · · · · ·    (input data, 1-deep)                 X [batch, 28, 28, 1]
# @ @ @ @ @ @ @ @ @ @ -- conv. layer 6x6x1=>6 stride 1        W1 [6, 6, 1, 6]        B1 [6]
# ∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶                                         Y1 [batch, 28, 28, 6]
#   @ @ @ @ @ @ @ @   -- conv. layer 5x5x6=>12 stride 2       W2 [5, 5, 6, 12]        B2 [12]
#   ∶∶∶∶∶∶∶∶∶∶∶∶∶∶∶                                           Y2 [batch, 14, 14, 12]
#     @ @ @ @ @ @     -- conv. layer 4x4x12=>24 stride 2      W3 [4, 4, 12, 24]       B3 [24]
#     ∶∶∶∶∶∶∶∶∶∶∶                                             Y3 [batch, 7, 7, 24] => reshaped to YY [batch, 7*7*24]
#      \x/x\x\x/ ✞    -- fully connected layer (relu+dropout) W4 [7*7*24, 200]       B4 [200]
#       · · · ·                                               Y4 [batch, 200]
#       \x/x\x/       -- fully connected layer (softmax)      W5 [200, 10]           B5 [10]
#        · · ·                                                Y [batch, 20]

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset_c)
  tf_test_dataset = tf.constant(test_dataset_c)
  
  #Variables.
  # variable learning rate
  lr = tf.placeholder(tf.float32)
  # pkeep for dropout
  pkeep = tf.placeholder(tf.float32)
  # three convolutional layers with their channel counts, and a
  # fully connected layer (tha last layer has 10 softmax neurons)
  L1 = 6  # first convolutional layer output depth
  L2 = 16  # second convolutional layer output depth
  L3 = 120  # third convolutional layer
  L4 = 84  # fully connected layer

  W1 = tf.Variable(tf.truncated_normal([6, 6, 1, L1], stddev=0.1))  # 6x6 patch, 1 input channel, L1 output channels
  B1 = tf.Variable(tf.constant(0.1, tf.float32, [L1]))
  W2 = tf.Variable(tf.truncated_normal([5, 5, L1, L2], stddev=0.1))
  B2 = tf.Variable(tf.constant(0.1, tf.float32, [L2]))
  W3 = tf.Variable(tf.truncated_normal([4, 4, L2, L3], stddev=0.1))
  B3 = tf.Variable(tf.constant(0.1, tf.float32, [L3]))

  W4 = tf.Variable(tf.truncated_normal([7 * 7 * L3, L4], stddev=0.1))
  B4 = tf.Variable(tf.constant(0.1, tf.float32, [L4]))
  W5 = tf.Variable(tf.truncated_normal([L4, 10], stddev=0.1))
  B5 = tf.Variable(tf.constant(0.1, tf.float32, [10]))



  # Model.
  def model(data, dropout=True):
    if dropout:
        stride = 1  # output is 28x28
        k = 2
        Y1 = tf.nn.relu(tf.nn.conv2d(data, W1, strides=[1, stride, stride, 1], padding='SAME') + B1)
        Y1 = tf.nn.max_pool(Y1, ksize=[1, 2, 2, 1], strides=[1, k, k, 1], padding='SAME')
        # after max_pool with stride 2 (the same as kernel) output is 14x14
        stride = 1  
        Y2 = tf.nn.relu(tf.nn.conv2d(Y1, W2, strides=[1, stride, stride, 1], padding='SAME') + B2)
        Y2 = tf.nn.max_pool(Y2, ksize=[1, 2, 2, 1], strides=[1, k, k, 1], padding='SAME')
        # after max_pool output is 7x7
        stride = 1 
        Y3 = tf.nn.relu(tf.nn.conv2d(Y2, W3, strides=[1, stride, stride, 1], padding='SAME') + B3)
        Y3 = tf.nn.max_pool(Y3, ksize=[1, 2, 2, 1], strides=[1, stride, stride, 1], padding='SAME')
        # again # after max_pool output is 7x7
        # reshape the output from the third convolution for the fully connected layer
        YY = tf.reshape(Y3, shape=[-1, 7 * 7 * L3])

        Y4 = tf.nn.relu(tf.matmul(YY, W4) + B4)
        Y4d = tf.nn.dropout(Y4, pkeep)

        return tf.matmul(Y4d, W5) + B5
    if not dropout:
        stride = 1  # output is 28x28
        k = 2
        Y1 = tf.nn.relu(tf.nn.conv2d(data, W1, strides=[1, stride, stride, 1], padding='SAME') + B1)
        Y1 = tf.nn.max_pool(Y1, ksize=[1, 2, 2, 1], strides=[1, k, k, 1], padding='SAME')
        # after max_pool with stride 2 (the same as kernel) output is 14x14
        stride = 1  
        Y2 = tf.nn.relu(tf.nn.conv2d(Y1, W2, strides=[1, stride, stride, 1], padding='SAME') + B2)
        Y2 = tf.nn.max_pool(Y2, ksize=[1, 2, 2, 1], strides=[1, k, k, 1], padding='SAME')
        # after max_pool output is 7x7
        stride = 1 
        Y3 = tf.nn.relu(tf.nn.conv2d(Y2, W3, strides=[1, stride, stride, 1], padding='SAME') + B3)
        Y3 = tf.nn.max_pool(Y3, ksize=[1, 2, 2, 1], strides=[1, stride, stride, 1], padding='SAME')
        # again # after max_pool output is 7x7
        # reshape the output from the third convolution for the fully connected layer
        YY = tf.reshape(Y3, shape=[-1, 7 * 7 * L3])

        Y4 = tf.nn.relu(tf.matmul(YY, W4) + B4)
        return tf.matmul(Y4, W5) + B5

 
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
#   batch = tf.Variable(0, trainable=False)
#   train_size = train_labels.shape[0]
#   learning_rate = tf.train.exponential_decay(0.01, 
#                                                batch, 
#                                                train_size,
#                                                0.001,
#                                                staircase = True)

#   optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=batch)
  optimizer = tf.train.AdagradOptimizer(0.07).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, False))

# %%
# %%time
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels_c.shape[0] - batch_size)
    batch_data = train_dataset_c[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels_c[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, pkeep : 0.5}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels_c))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels_c))

# bs = 16, Layers: 6,16,120,84, Adagrad(0.05), num_steps = 3001 - 93%
# bs = 16, Layers: 8,16,120,84, Adagrad(0.05), num_steps = 3001 - 90%
# bs = 16, Layers: 4,16,120,84, Adagrad(0.05), num_steps = 3001 - 93%
# bs = 32, Layers: 4,16,120,84, Adagrad(0.05), num_steps = 3001 - 93.8%
# bs = 64, Layers: 4,16,120,84, Adagrad(0.05), num_steps = 3001 - 94.2%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.05), num_steps = 3001 - 94.3%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.04), num_steps = 3001 - 95.3%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.03), num_steps = 6001 - 95.2%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.06), num_steps = 6001 - 95.5%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.07), num_steps = 6001 - 95.7%
# bs = 128, Layers: 4,16,120,100, Adagrad(0.07), num_steps = 6001 - 95.3%
# bs = 128, Layers: 4,16,120,60, Adagrad(0.07), num_steps = 6001 - 95.5%
# bs = 128, Layers: 4,16,120,42, Adagrad(0.07), num_steps = 6001 - 95.5%
# bs = 256, Layers: 4,16,120,84, Adagrad(0.07), num_steps = 6001 - 95.5%
# bs = 64, Layers: 4,16,120,84, Adagrad(0.07), num_steps = 6001 - 95.%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.08), num_steps = 6001 - 95.5%
# bs = 256, Layers: 4,16,120,84, Adagrad(0.08), num_steps = 6001 - 95.8%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.05), num_steps = 30001 - 96.4%
# bs = 128, Layers: 4,16,120,84, Adagrad(0.05), num_steps = 60001 - 96.8%
# bs = 128, Layers: 6,16,120,84, Adam(0.01), num_steps = 60001 - 92.2%
# bs = 128, Layers: 6,16,120,84, Adam(0.001), num_steps = 60001 - 95%
# bs = 128, Layers: 6,16,120,84, Adam(0.0001), num_steps = 60001 - 91.9%
# bs = 128, Layers: 6,16,120,84, Adam(0.01 - 0.0001), num_steps = 60001 - 92.1%
# bs = 128, Layers: 6,16,120,84, Adagrad(0.05), num_steps = 60001 - 95.8%
# bs = 128, Layers: 6,16,120,84, Adagrad(0.05), num_steps = 100001 - 97% - 2.36 hour
# bs = 128, Layers: 4,16,120,84, Adagrad(0.07), num_steps = 100001 - 96.9% - 2.36 hour
# bs = 128, Layers: 6,16,120,84, Adagrad(0.07), num_steps = 100001 - 96.9% - 2.36 hour
# Out:
# Initialized
# Minibatch loss at step 0: 4.140816
# Minibatch accuracy: 9.4%
# Validation accuracy: 13.5%
# Minibatch loss at step 50: 1.417216
# Minibatch accuracy: 51.6%
# Validation accuracy: 66.8%
# Minibatch loss at step 100: 0.899910
# Minibatch accuracy: 68.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 150: 0.609660
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 200: 0.721183
# Minibatch accuracy: 76.6%
# Validation accuracy: 83.1%
# Minibatch loss at step 250: 0.561992
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.4%
# Minibatch loss at step 300: 0.604293
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 350: 0.664483
# Minibatch accuracy: 75.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 400: 0.771832
# Minibatch accuracy: 77.3%
# Validation accuracy: 85.6%
# Minibatch loss at step 450: 0.542106
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 500: 0.605320
# Minibatch accuracy: 82.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 550: 0.483050
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.7%
# Minibatch loss at step 600: 0.777356
# Minibatch accuracy: 80.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 650: 0.537668
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 700: 0.442114
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.3%
# Minibatch loss at step 750: 0.449272
# Minibatch accuracy: 85.9%
# Validation accuracy: 87.5%
# Minibatch loss at step 800: 0.315481
# Minibatch accuracy: 92.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 850: 0.497602
# Minibatch accuracy: 86.7%
# Validation accuracy: 87.5%
# Minibatch loss at step 900: 0.607625
# Minibatch accuracy: 83.6%
# Validation accuracy: 88.0%
# Minibatch loss at step 950: 0.439499
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 1000: 0.522818
# Minibatch accuracy: 83.6%
# Validation accuracy: 88.2%
# Minibatch loss at step 1050: 0.431752
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.1%
# Minibatch loss at step 1100: 0.656215
# Minibatch accuracy: 78.9%
# Validation accuracy: 87.7%
# Minibatch loss at step 1150: 0.545906
# Minibatch accuracy: 82.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 1200: 0.327923
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 1250: 0.512622
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.5%
# Minibatch loss at step 1300: 0.381730
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.0%
# Minibatch loss at step 1350: 0.463437
# Minibatch accuracy: 85.9%
# Validation accuracy: 88.9%
# Minibatch loss at step 1400: 0.478586
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.7%
# Minibatch loss at step 1450: 0.576435
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.7%
# Minibatch loss at step 1500: 0.370675
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.1%
# Minibatch loss at step 1550: 0.487462
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 1600: 0.501365
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 1650: 0.351595
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Minibatch loss at step 1700: 0.363413
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 1750: 0.274357
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.4%
# Minibatch loss at step 1800: 0.276649
# Minibatch accuracy: 93.0%
# Validation accuracy: 89.3%
# Minibatch loss at step 1850: 0.457749
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.4%
# Minibatch loss at step 1900: 0.530071
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 1950: 0.261942
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.3%
# Minibatch loss at step 2000: 0.357988
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Minibatch loss at step 2050: 0.490539
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 2100: 0.408291
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.5%
# Minibatch loss at step 2150: 0.376340
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.7%
# Minibatch loss at step 2200: 0.287606
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 2250: 0.414099
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.7%
# Minibatch loss at step 2300: 0.346608
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.6%
# Minibatch loss at step 2350: 0.315395
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.7%
# Minibatch loss at step 2400: 0.430651
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.6%
# Minibatch loss at step 2450: 0.353952
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.9%
# Minibatch loss at step 2500: 0.486688
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.7%
# Minibatch loss at step 2550: 0.314271
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.9%
# Minibatch loss at step 2600: 0.501214
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 2650: 0.495781
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.6%
# Minibatch loss at step 2700: 0.414862
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.4%
# Minibatch loss at step 2750: 0.445132
# Minibatch accuracy: 88.3%
# Validation accuracy: 89.5%
# Minibatch loss at step 2800: 0.342335
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 2850: 0.360578
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.8%
# Minibatch loss at step 2900: 0.389112
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 2950: 0.367494
# Minibatch accuracy: 90.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 3000: 0.359980
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.1%
# Minibatch loss at step 3050: 0.427160
# Minibatch accuracy: 83.6%
# Validation accuracy: 89.9%
# Minibatch loss at step 3100: 0.463010
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.2%
# Minibatch loss at step 3150: 0.310801
# Minibatch accuracy: 92.2%
# Validation accuracy: 89.9%
# Minibatch loss at step 3200: 0.374798
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 3250: 0.328210
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.3%
# Minibatch loss at step 3300: 0.365594
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Minibatch loss at step 3350: 0.460979
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.1%
# Minibatch loss at step 3400: 0.287764
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 3450: 0.195358
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 3500: 0.399004
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.0%
# Minibatch loss at step 3550: 0.432247
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.3%
# Minibatch loss at step 3600: 0.424284
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 3650: 0.446712
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.5%
# Minibatch loss at step 3700: 0.433425
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.3%
# Minibatch loss at step 3750: 0.242607
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 3800: 0.360090
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.2%
# Minibatch loss at step 3850: 0.332023
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 3900: 0.275729
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 3950: 0.236509
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.2%
# Minibatch loss at step 4000: 0.324758
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 4050: 0.235798
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.4%
# Minibatch loss at step 4100: 0.223310
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 4150: 0.332621
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.5%
# Minibatch loss at step 4200: 0.319179
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 4250: 0.350567
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 4300: 0.520044
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.3%
# Minibatch loss at step 4350: 0.445343
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 4400: 0.396003
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.4%
# Minibatch loss at step 4450: 0.306122
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.4%
# Minibatch loss at step 4500: 0.183432
# Minibatch accuracy: 96.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 4550: 0.329879
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 4600: 0.295143
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 4650: 0.333241
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.7%
# Minibatch loss at step 4700: 0.501882
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 4750: 0.222544
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 4800: 0.351486
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.7%
# Minibatch loss at step 4850: 0.354538
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.7%
# Minibatch loss at step 4900: 0.328308
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 4950: 0.364648
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 5000: 0.384628
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.7%
# Minibatch loss at step 5050: 0.256014
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 5100: 0.589088
# Minibatch accuracy: 82.8%
# Validation accuracy: 91.1%
# Minibatch loss at step 5150: 0.255437
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.9%
# Minibatch loss at step 5200: 0.315267
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.8%
# Minibatch loss at step 5250: 0.362079
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 5300: 0.212440
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 5350: 0.211868
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 5400: 0.411417
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 5450: 0.302751
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 5500: 0.262507
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 5550: 0.352833
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.9%
# Minibatch loss at step 5600: 0.302716
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.7%
# Minibatch loss at step 5650: 0.282444
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 5700: 0.319614
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.7%
# Minibatch loss at step 5750: 0.198075
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.9%
# Minibatch loss at step 5800: 0.280248
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 5850: 0.237566
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.7%
# Minibatch loss at step 5900: 0.431565
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.9%
# Minibatch loss at step 5950: 0.277598
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 6000: 0.438695
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.0%
# Minibatch loss at step 6050: 0.315397
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.9%
# Minibatch loss at step 6100: 0.371309
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.1%
# Minibatch loss at step 6150: 0.272012
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 6200: 0.419182
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 6250: 0.287671
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 6300: 0.275054
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.8%
# Minibatch loss at step 6350: 0.329445
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.9%
# Minibatch loss at step 6400: 0.271369
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.1%
# Minibatch loss at step 6450: 0.540242
# Minibatch accuracy: 85.2%
# Validation accuracy: 91.2%
# Minibatch loss at step 6500: 0.350925
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.0%
# Minibatch loss at step 6550: 0.323570
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.1%
# Minibatch loss at step 6600: 0.317072
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.2%
# Minibatch loss at step 6650: 0.324938
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.1%
# Minibatch loss at step 6700: 0.298344
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.1%
# Minibatch loss at step 6750: 0.501767
# Minibatch accuracy: 84.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 6800: 0.417278
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.0%
# Minibatch loss at step 6850: 0.349953
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 6900: 0.422962
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.2%
# Minibatch loss at step 6950: 0.250099
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 7000: 0.370130
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 7050: 0.383690
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.2%
# Minibatch loss at step 7100: 0.196081
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 7150: 0.250442
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.3%
# Minibatch loss at step 7200: 0.356705
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 7250: 0.345705
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.3%
# Minibatch loss at step 7300: 0.219846
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 7350: 0.353861
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.2%
# Minibatch loss at step 7400: 0.356545
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.2%
# Minibatch loss at step 7450: 0.476926
# Minibatch accuracy: 84.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 7500: 0.287245
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.2%
# Minibatch loss at step 7550: 0.225498
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 7600: 0.452121
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.3%
# Minibatch loss at step 7650: 0.273175
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 7700: 0.324344
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.4%
# Minibatch loss at step 7750: 0.515465
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.3%
# Minibatch loss at step 7800: 0.344442
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 7850: 0.343796
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 7900: 0.286270
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.2%
# Minibatch loss at step 7950: 0.402944
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.4%
# Minibatch loss at step 8000: 0.510663
# Minibatch accuracy: 85.2%
# Validation accuracy: 91.4%
# Minibatch loss at step 8050: 0.261054
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.3%
# Minibatch loss at step 8100: 0.254120
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 8150: 0.316970
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 8200: 0.379745
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.3%
# Minibatch loss at step 8250: 0.320517
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 8300: 0.289681
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 8350: 0.551698
# Minibatch accuracy: 84.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 8400: 0.326375
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.3%
# Minibatch loss at step 8450: 0.187521
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.4%
# Minibatch loss at step 8500: 0.373525
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.1%
# Minibatch loss at step 8550: 0.288883
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 8600: 0.320191
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 8650: 0.360250
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 8700: 0.342307
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.4%
# Minibatch loss at step 8750: 0.438851
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 8800: 0.348557
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.6%
# Minibatch loss at step 8850: 0.283197
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.4%
# Minibatch loss at step 8900: 0.388028
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.5%
# Minibatch loss at step 8950: 0.211136
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 9000: 0.311918
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 9050: 0.287912
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 9100: 0.551311
# Minibatch accuracy: 85.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 9150: 0.297324
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 9200: 0.485146
# Minibatch accuracy: 85.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 9250: 0.223340
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.2%
# Minibatch loss at step 9300: 0.432949
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.4%
# Minibatch loss at step 9350: 0.258200
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 9400: 0.375331
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.5%
# Minibatch loss at step 9450: 0.366652
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 9500: 0.419371
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 9550: 0.323879
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 9600: 0.278154
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.9%
# Minibatch loss at step 9650: 0.344517
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 9700: 0.316020
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 9750: 0.428605
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.6%
# Minibatch loss at step 9800: 0.235408
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 9850: 0.259169
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 9900: 0.310660
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 9950: 0.178320
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 10000: 0.229344
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.5%
# Minibatch loss at step 10050: 0.249216
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 10100: 0.361334
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.4%
# Minibatch loss at step 10150: 0.230606
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 10200: 0.204577
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 10250: 0.269655
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 10300: 0.399509
# Minibatch accuracy: 85.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 10350: 0.316087
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 10400: 0.302956
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 10450: 0.244855
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 10500: 0.337932
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.7%
# Minibatch loss at step 10550: 0.389446
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 10600: 0.211600
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 10650: 0.508622
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.7%
# Minibatch loss at step 10700: 0.277515
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 10750: 0.328824
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 10800: 0.255224
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 10850: 0.179525
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 10900: 0.221176
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 10950: 0.214009
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 11000: 0.362766
# Minibatch accuracy: 84.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 11050: 0.381860
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 11100: 0.302143
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 11150: 0.341121
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 11200: 0.279044
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 11250: 0.117546
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 11300: 0.374097
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 11350: 0.197898
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 11400: 0.381971
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 11450: 0.326821
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 11500: 0.142201
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 11550: 0.305651
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 11600: 0.255978
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 11650: 0.272140
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 11700: 0.323678
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 11750: 0.181739
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 11800: 0.202412
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 11850: 0.363568
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 11900: 0.378440
# Minibatch accuracy: 84.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 11950: 0.289551
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 12000: 0.260831
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 12050: 0.236498
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 12100: 0.282611
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 12150: 0.155993
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 12200: 0.384250
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 12250: 0.330954
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 12300: 0.269331
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 12350: 0.347229
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 12400: 0.360854
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 12450: 0.352535
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 12500: 0.391035
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 12550: 0.414504
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 12600: 0.217191
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 12650: 0.179377
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 12700: 0.310134
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 12750: 0.240941
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 12800: 0.210485
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 12850: 0.280108
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.0%
# Minibatch loss at step 12900: 0.285181
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 12950: 0.287580
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 13000: 0.278830
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 13050: 0.325821
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.0%
# Minibatch loss at step 13100: 0.309027
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 13150: 0.402387
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 13200: 0.258475
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.8%
# Minibatch loss at step 13250: 0.238181
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 13300: 0.203564
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 13350: 0.320693
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 13400: 0.183752
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 13450: 0.237476
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 13500: 0.232669
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 13550: 0.262309
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.0%
# Minibatch loss at step 13600: 0.163464
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 13650: 0.199357
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 13700: 0.276445
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 13750: 0.184146
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.8%
# Minibatch loss at step 13800: 0.349666
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.8%
# Minibatch loss at step 13850: 0.299544
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 13900: 0.343092
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 13950: 0.211842
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 14000: 0.196275
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 14050: 0.262328
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 14100: 0.272444
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 14150: 0.220594
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 14200: 0.126240
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.9%
# Minibatch loss at step 14250: 0.258496
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 14300: 0.288682
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.9%
# Minibatch loss at step 14350: 0.358015
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 14400: 0.355461
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 14450: 0.376438
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.9%
# Minibatch loss at step 14500: 0.313691
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 14550: 0.256522
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 14600: 0.097965
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.1%
# Minibatch loss at step 14650: 0.301403
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 14700: 0.385927
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.9%
# Minibatch loss at step 14750: 0.248240
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 14800: 0.372503
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.9%
# Minibatch loss at step 14850: 0.421257
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 14900: 0.233672
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 14950: 0.105964
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.0%
# Minibatch loss at step 15000: 0.259226
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 15050: 0.393821
# Minibatch accuracy: 85.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 15100: 0.196678
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 15150: 0.345702
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 15200: 0.388124
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.9%
# Minibatch loss at step 15250: 0.178121
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 15300: 0.338301
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 15350: 0.408850
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 15400: 0.203322
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 15450: 0.158893
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 15500: 0.184926
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 15550: 0.403134
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 15600: 0.184005
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 15650: 0.248488
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 15700: 0.227966
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 15750: 0.270134
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 15800: 0.423742
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 15850: 0.305931
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 15900: 0.255333
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 15950: 0.290582
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 16000: 0.278424
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 16050: 0.260981
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 16100: 0.264731
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 16150: 0.191599
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 16200: 0.246333
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 16250: 0.199566
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 16300: 0.188104
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 16350: 0.198452
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 16400: 0.323955
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 16450: 0.256467
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.2%
# Minibatch loss at step 16500: 0.475482
# Minibatch accuracy: 85.9%
# Validation accuracy: 92.2%
# Minibatch loss at step 16550: 0.308109
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.3%
# Minibatch loss at step 16600: 0.248760
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 16650: 0.303293
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 16700: 0.201418
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 16750: 0.153453
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 16800: 0.427894
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 16850: 0.281123
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 16900: 0.190744
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.1%
# Minibatch loss at step 16950: 0.364973
# Minibatch accuracy: 87.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 17000: 0.332943
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 17050: 0.214014
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 17100: 0.167216
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.0%
# Minibatch loss at step 17150: 0.400841
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 17200: 0.335398
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.1%
# Minibatch loss at step 17250: 0.311116
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 17300: 0.199680
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 17350: 0.337120
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.3%
# Minibatch loss at step 17400: 0.244639
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 17450: 0.257368
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.2%
# Minibatch loss at step 17500: 0.192692
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.3%
# Minibatch loss at step 17550: 0.199182
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 17600: 0.304057
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 17650: 0.233045
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 17700: 0.277454
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.1%
# Minibatch loss at step 17750: 0.264053
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 17800: 0.325434
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.1%
# Minibatch loss at step 17850: 0.214043
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.2%
# Minibatch loss at step 17900: 0.297067
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 17950: 0.258592
# Minibatch accuracy: 87.5%
# Validation accuracy: 92.2%
# Minibatch loss at step 18000: 0.232852
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 18050: 0.257735
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 18100: 0.190028
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 18150: 0.209957
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 18200: 0.397541
# Minibatch accuracy: 87.5%
# Validation accuracy: 92.3%
# Minibatch loss at step 18250: 0.165783
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.3%
# Minibatch loss at step 18300: 0.341134
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 18350: 0.212272
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 18400: 0.303430
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 18450: 0.273800
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 18500: 0.234247
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.1%
# Minibatch loss at step 18550: 0.389820
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 18600: 0.271641
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.3%
# Minibatch loss at step 18650: 0.142559
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 18700: 0.261471
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 18750: 0.195844
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 18800: 0.305486
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 18850: 0.327108
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.3%
# Minibatch loss at step 18900: 0.227102
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 18950: 0.174672
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.2%
# Minibatch loss at step 19000: 0.253323
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 19050: 0.292458
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 19100: 0.223030
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 19150: 0.243858
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 19200: 0.213043
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 19250: 0.218360
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 19300: 0.202164
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 19350: 0.284207
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 19400: 0.404921
# Minibatch accuracy: 85.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 19450: 0.354256
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 19500: 0.266033
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 19550: 0.248345
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 19600: 0.236741
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 19650: 0.256015
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 19700: 0.240315
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 19750: 0.222697
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 19800: 0.196702
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 19850: 0.220865
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 19900: 0.324624
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.3%
# Minibatch loss at step 19950: 0.257577
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 20000: 0.122982
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.1%
# Minibatch loss at step 20050: 0.132640
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.3%
# Minibatch loss at step 20100: 0.240364
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 20150: 0.227169
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 20200: 0.165819
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 20250: 0.154816
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 20300: 0.179536
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 20350: 0.266401
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 20400: 0.316760
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.3%
# Minibatch loss at step 20450: 0.148789
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.3%
# Minibatch loss at step 20500: 0.292032
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 20550: 0.105455
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 20600: 0.203641
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 20650: 0.244489
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 20700: 0.388414
# Minibatch accuracy: 85.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 20750: 0.298653
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 20800: 0.164212
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 20850: 0.237091
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.1%
# Minibatch loss at step 20900: 0.387578
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.2%
# Minibatch loss at step 20950: 0.284117
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 21000: 0.190201
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 21050: 0.169162
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 21100: 0.240480
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 21150: 0.166951
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.5%
# Minibatch loss at step 21200: 0.205350
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 21250: 0.245353
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 21300: 0.265184
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 21350: 0.369940
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 21400: 0.236047
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 21450: 0.255153
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 21500: 0.143986
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.4%
# Minibatch loss at step 21550: 0.275198
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 21600: 0.365369
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.1%
# Minibatch loss at step 21650: 0.234939
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 21700: 0.254787
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 21750: 0.326087
# Minibatch accuracy: 85.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 21800: 0.202110
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 21850: 0.241851
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 21900: 0.381031
# Minibatch accuracy: 85.9%
# Validation accuracy: 92.4%
# Minibatch loss at step 21950: 0.249672
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.4%
# Minibatch loss at step 22000: 0.221328
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 22050: 0.154225
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.5%
# Minibatch loss at step 22100: 0.186327
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 22150: 0.221791
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 22200: 0.240565
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.5%
# Minibatch loss at step 22250: 0.315687
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.3%
# Minibatch loss at step 22300: 0.248918
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 22350: 0.214550
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.4%
# Minibatch loss at step 22400: 0.287717
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.3%
# Minibatch loss at step 22450: 0.204633
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 22500: 0.196950
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 22550: 0.175766
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 22600: 0.208331
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 22650: 0.191018
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 22700: 0.326838
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.6%
# Minibatch loss at step 22750: 0.286814
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.2%
# Minibatch loss at step 22800: 0.208007
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.5%
# Minibatch loss at step 22850: 0.133358
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.5%
# Minibatch loss at step 22900: 0.312159
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 22950: 0.294632
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 23000: 0.303841
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.2%
# Minibatch loss at step 23050: 0.268991
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 23100: 0.281446
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.4%
# Minibatch loss at step 23150: 0.198636
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 23200: 0.250604
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 23250: 0.151734
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 23300: 0.288890
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 23350: 0.228849
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.2%
# Minibatch loss at step 23400: 0.247826
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 23450: 0.237057
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 23500: 0.362170
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.2%
# Minibatch loss at step 23550: 0.112383
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 23600: 0.224310
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 23650: 0.294053
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 23700: 0.195881
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.3%
# Minibatch loss at step 23750: 0.258828
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 23800: 0.205903
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 23850: 0.207719
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 23900: 0.294619
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.3%
# Minibatch loss at step 23950: 0.350743
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 24000: 0.251621
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.3%
# Minibatch loss at step 24050: 0.205321
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.4%
# Minibatch loss at step 24100: 0.244093
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.2%
# Minibatch loss at step 24150: 0.239920
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.4%
# Minibatch loss at step 24200: 0.200430
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.3%
# Minibatch loss at step 24250: 0.294340
# Minibatch accuracy: 87.5%
# Validation accuracy: 92.5%
# Minibatch loss at step 24300: 0.272666
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.4%
# Minibatch loss at step 24350: 0.203740
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.5%
# Minibatch loss at step 24400: 0.193848
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.5%
# Minibatch loss at step 24450: 0.222319
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.2%
# Minibatch loss at step 24500: 0.158273
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.3%
# Minibatch loss at step 24550: 0.265977
# Minibatch accuracy: 89.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 24600: 0.247973
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 24650: 0.304897
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 24700: 0.144675
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.1%
# Minibatch loss at step 24750: 0.183655
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 24800: 0.217412
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 24850: 0.294251
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.6%
# Minibatch loss at step 24900: 0.162722
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.5%
# Minibatch loss at step 24950: 0.288955
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.5%
# Minibatch loss at step 25000: 0.314600
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.5%
# Minibatch loss at step 25050: 0.199946
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 25100: 0.152118
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.7%
# Minibatch loss at step 25150: 0.317958
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 25200: 0.140109
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 25250: 0.319821
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.4%
# Minibatch loss at step 25300: 0.231777
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 25350: 0.260782
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.5%
# Minibatch loss at step 25400: 0.161571
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.5%
# Minibatch loss at step 25450: 0.131598
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.3%
# Minibatch loss at step 25500: 0.178876
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.5%
# Minibatch loss at step 25550: 0.133693
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 25600: 0.121991
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.4%
# Minibatch loss at step 25650: 0.331393
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.5%
# Minibatch loss at step 25700: 0.284671
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 25750: 0.183239
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.4%
# Minibatch loss at step 25800: 0.228618
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.5%
# Minibatch loss at step 25850: 0.234269
# Minibatch accuracy: 91.4%
# Validation accuracy: 92.3%
# Minibatch loss at step 25900: 0.183005
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.5%
# Minibatch loss at step 25950: 0.169782
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.4%
# Minibatch loss at step 26000: 0.160590
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.5%
# Minibatch loss at step 26050: 0.107009
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.4%
# Minibatch loss at step 26100: 0.189951
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.5%
# Minibatch loss at step 26150: 0.184132
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.5%
# ...
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 91450: 0.167719
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 91500: 0.050428
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 91550: 0.148647
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.7%
# Minibatch loss at step 91600: 0.096844
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.7%
# Minibatch loss at step 91650: 0.109449
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 91700: 0.108873
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 91750: 0.135649
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 91800: 0.122986
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 91850: 0.115803
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 91900: 0.122079
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 91950: 0.156539
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.9%
# Minibatch loss at step 92000: 0.106472
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.7%
# Minibatch loss at step 92050: 0.104770
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 92100: 0.152528
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 92150: 0.042016
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 92200: 0.048782
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 92250: 0.181838
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.9%
# Minibatch loss at step 92300: 0.164408
# Minibatch accuracy: 92.2%
# Validation accuracy: 93.0%
# Minibatch loss at step 92350: 0.041671
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.9%
# Minibatch loss at step 92400: 0.074604
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 92450: 0.156809
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 92500: 0.065824
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 92550: 0.123715
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 92600: 0.132783
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 92650: 0.098367
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 92700: 0.095636
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 92750: 0.069274
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 92800: 0.109812
# Minibatch accuracy: 96.1%
# Validation accuracy: 93.1%
# Minibatch loss at step 92850: 0.154275
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 92900: 0.162586
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 92950: 0.088265
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 93000: 0.070362
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.7%
# Minibatch loss at step 93050: 0.116146
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 93100: 0.126594
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 93150: 0.093637
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 93200: 0.109140
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 93250: 0.092089
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 93300: 0.104738
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 93350: 0.086048
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 93400: 0.083472
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 93450: 0.154878
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 93500: 0.178491
# Minibatch accuracy: 93.8%
# Validation accuracy: 93.0%
# Minibatch loss at step 93550: 0.065306
# Minibatch accuracy: 97.7%
# Validation accuracy: 93.0%
# Minibatch loss at step 93600: 0.125875
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 93650: 0.194653
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 93700: 0.068200
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 93750: 0.199025
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 93800: 0.119371
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 93850: 0.171334
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 93900: 0.171759
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.9%
# Minibatch loss at step 93950: 0.113926
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 94000: 0.108261
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 94050: 0.118660
# Minibatch accuracy: 96.1%
# Validation accuracy: 93.1%
# Minibatch loss at step 94100: 0.101958
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 94150: 0.046605
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 94200: 0.081705
# Minibatch accuracy: 96.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 94250: 0.085059
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 94300: 0.129862
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 94350: 0.142478
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.9%
# Minibatch loss at step 94400: 0.076500
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 94450: 0.145833
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 94500: 0.100596
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 94550: 0.079857
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 94600: 0.107033
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 94650: 0.153803
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 94700: 0.094221
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 94750: 0.123705
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 94800: 0.115833
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 94850: 0.061245
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 94900: 0.138804
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 94950: 0.044179
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 95000: 0.103082
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.7%
# Minibatch loss at step 95050: 0.136474
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 95100: 0.178715
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 95150: 0.129323
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 95200: 0.160611
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 95250: 0.116697
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 95300: 0.105215
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 95350: 0.103532
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 95400: 0.191555
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 95450: 0.105584
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 95500: 0.107821
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 95550: 0.134836
# Minibatch accuracy: 94.5%
# Validation accuracy: 93.0%
# Minibatch loss at step 95600: 0.121939
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 95650: 0.126488
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 95700: 0.080862
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 95750: 0.072651
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 95800: 0.080986
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 95850: 0.060124
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 95900: 0.083721
# Minibatch accuracy: 96.9%
# Validation accuracy: 93.0%
# Minibatch loss at step 95950: 0.100346
# Minibatch accuracy: 96.1%
# Validation accuracy: 93.0%
# Minibatch loss at step 96000: 0.079019
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 96050: 0.077718
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 96100: 0.079091
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.7%
# Minibatch loss at step 96150: 0.161435
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 96200: 0.132253
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 96250: 0.118227
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 96300: 0.077177
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 96350: 0.132798
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 96400: 0.101132
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 96450: 0.040941
# Minibatch accuracy: 98.4%
# Validation accuracy: 93.0%
# Minibatch loss at step 96500: 0.087741
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 96550: 0.022772
# Minibatch accuracy: 99.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 96600: 0.045881
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 96650: 0.081488
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 96700: 0.103579
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 96750: 0.104383
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 96800: 0.148210
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 96850: 0.178354
# Minibatch accuracy: 93.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 96900: 0.097604
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 96950: 0.071335
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 97000: 0.130543
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 97050: 0.097524
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 97100: 0.056265
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 97150: 0.096358
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 97200: 0.059142
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.8%
# Minibatch loss at step 97250: 0.099813
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 97300: 0.117238
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 97350: 0.118039
# Minibatch accuracy: 95.3%
# Validation accuracy: 93.0%
# Minibatch loss at step 97400: 0.110890
# Minibatch accuracy: 94.5%
# Validation accuracy: 93.0%
# Minibatch loss at step 97450: 0.077283
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 97500: 0.071813
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 97550: 0.070454
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 97600: 0.141229
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 97650: 0.058555
# Minibatch accuracy: 98.4%
# Validation accuracy: 92.7%
# Minibatch loss at step 97700: 0.138320
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 97750: 0.098627
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 97800: 0.100889
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 97850: 0.075211
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.8%
# Minibatch loss at step 97900: 0.123740
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 97950: 0.068988
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 98000: 0.196814
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 98050: 0.079747
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 98100: 0.137327
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.7%
# Minibatch loss at step 98150: 0.084823
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 98200: 0.080438
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.7%
# Minibatch loss at step 98250: 0.089895
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.8%
# Minibatch loss at step 98300: 0.197390
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.7%
# Minibatch loss at step 98350: 0.123108
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 98400: 0.070859
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 98450: 0.115566
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.8%
# Minibatch loss at step 98500: 0.148615
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 98550: 0.258133
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 98600: 0.174732
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.7%
# Minibatch loss at step 98650: 0.120373
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 98700: 0.142688
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 98750: 0.167755
# Minibatch accuracy: 93.8%
# Validation accuracy: 92.8%
# Minibatch loss at step 98800: 0.136343
# Minibatch accuracy: 93.0%
# Validation accuracy: 93.0%
# Minibatch loss at step 98850: 0.105079
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 98900: 0.136148
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.7%
# Minibatch loss at step 98950: 0.076618
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.7%
# Minibatch loss at step 99000: 0.134682
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 99050: 0.127330
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.9%
# Minibatch loss at step 99100: 0.071380
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 99150: 0.162442
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 99200: 0.106654
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 99250: 0.172951
# Minibatch accuracy: 93.0%
# Validation accuracy: 92.9%
# Minibatch loss at step 99300: 0.127824
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.9%
# Minibatch loss at step 99350: 0.120172
# Minibatch accuracy: 95.3%
# Validation accuracy: 92.8%
# Minibatch loss at step 99400: 0.082429
# Minibatch accuracy: 97.7%
# Validation accuracy: 92.7%
# Minibatch loss at step 99450: 0.097605
# Minibatch accuracy: 94.5%
# Validation accuracy: 93.0%
# Minibatch loss at step 99500: 0.136769
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 99550: 0.071879
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 99600: 0.251747
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.8%
# Minibatch loss at step 99650: 0.082429
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.9%
# Minibatch loss at step 99700: 0.060607
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 99750: 0.112768
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.8%
# Minibatch loss at step 99800: 0.210856
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.8%
# Minibatch loss at step 99850: 0.158418
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Minibatch loss at step 99900: 0.091192
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.9%
# Minibatch loss at step 99950: 0.158213
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.8%
# Minibatch loss at step 100000: 0.101727
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.9%
# Test accuracy: 96.9%
# CPU times: user 16h 18min 23s, sys: 1h 55min 29s, total: 18h 13min 52s
# Wall time: 2h 54min 46s

# %% [markdown]
# ### a post on accuracy intervals and significance from udacity forum
# ```
# With my physics data analysis background, I'd claim an algo has been improved if the change in accuracy is beyond 3 standard deviations (3 sigmas). If it is smaller than 2 sigma there is 5% chance the better accuracy is just a fluke.
# To be specific, for our assignment we have N=10k images in the test_dataset.
# Let's pick accuracy(test_dataset)=0.94 (using fractions instead of % is better here).
#
# acc=0.94 means there where B=(1-acc)*N= 600 miss-classified images.
#
# Statistically speaking, 1 std error for B is sqrt(B)=24.5, hence 3 sigma = 73 images.
# The 3sigma error for acc=0.940 is 73/N= 0.007 .
#
# This means any other algorithm using 10k test images and yielding accuracy between 93.3% and 94.7% is statistically consistent with the base algo delivering accuracy of 94.0%.
#
# To claim an algorithm is better one needs either:
# * keep 10k test images and improve accuracy beyond 94.7 % or
# * use larger set of test images to reduce statistical error for the accuracy or
# * for the same 10k test images confirm exactly the same images were correctly identified plus few more correct identifications were made.
# ```

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# ### Code of endri.deliu from udacity forum

# %%
batch_size = 16
patch_size = 3
depth = 16
num_hidden = 705
num_hidden_last = 205

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layerconv1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layerconv1_biases = tf.Variable(tf.zeros([depth]))
  layerconv2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth * 2], stddev=0.1))
  layerconv2_biases = tf.Variable(tf.zeros([depth * 2]))
  
  layerconv3_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth * 2, depth * 4], stddev=0.03))
  layerconv3_biases = tf.Variable(tf.zeros([depth * 4]))
  
  layerconv4_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth * 4, depth * 4], stddev=0.03))
  layerconv4_biases = tf.Variable(tf.zeros([depth * 4]))
  

  layerconv5_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth * 4, depth * 16], stddev=0.03))
  layerconv5_biases = tf.Variable(tf.zeros([depth * 16]))

    
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 7 * image_size / 7 * (depth * 4), num_hidden], stddev=0.03))
  layer3_biases = tf.Variable(tf.zeros([num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_hidden_last], stddev=0.0532))
  layer4_biases = tf.Variable(tf.zeros([num_hidden_last]))
  
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden_last, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.zeros([num_labels]))
  

  # Model.
  def model(data, use_dropout=False):
    conv = tf.nn.conv2d(data, layerconv1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.elu(conv + layerconv1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layerconv2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.elu(conv + layerconv2_biases)
    #pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    

    conv = tf.nn.conv2d(hidden, layerconv3_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.elu(conv + layerconv3_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    # norm1
    # norm1 = tf.nn.lrn(pool, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)
    
    conv = tf.nn.conv2d(pool, layerconv4_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.elu(conv + layerconv4_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    # norm1 = tf.nn.lrn(pool, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

    
    conv = tf.nn.conv2d(pool, layerconv5_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.elu(conv + layerconv5_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    # norm1 = tf.nn.lrn(pool, 4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)
    
    shape = pool.get_shape().as_list()
    print shape
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.elu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    if use_dropout:
        hidden = tf.nn.dropout(hidden, 0.75)
    
    nn_hidden_layer = tf.matmul(hidden, layer4_weights) + layer4_biases
    hidden = tf.nn.elu(nn_hidden_layer)
    
    if use_dropout:
        hidden = tf.nn.dropout(hidden, 0.75)
    
    
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset, True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  global_step = tf.Variable(0)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.1, global_step, 3000, 0.86, staircase=True)
  
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))


num_steps = 5001
# original 95001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print "Minibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
      print time.ctime()
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)

# %% [markdown]
# ### Code of cobi.bento from udacity forum

# %%
batch_size = 16
num_channels = 1

c1_depth = 6
c1_ker_sz = 5
c3_depth = 16
c3_ker_sz = 6
c5_depth = 120
c5_ker_sz = 6

num_hidden = 84

graph = tf.Graph()

with graph.as_default():
    
        # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    # Variables.
    c1_weights = tf.Variable(tf.truncated_normal(
      [c1_ker_sz, c1_ker_sz, num_channels, c1_depth], stddev=0.1))
    c1_biases = tf.Variable(tf.zeros([c1_depth]))
    c3_weights = tf.Variable(tf.truncated_normal(
      [c3_ker_sz, c3_ker_sz, c1_depth, c3_depth], stddev=0.1))
    c3_biases = tf.Variable(tf.constant(1.0, shape=[c3_depth]))
    c5_weights = tf.Variable(tf.truncated_normal(
      [c5_ker_sz, c5_ker_sz, c3_depth, c5_depth], stddev=0.1))
    c5_biases = tf.Variable(tf.constant(1.0, shape=[c5_depth]))
    c5_conv_dim = (((((image_size+1)//2) + 1) // 2) + 1 )//2
    fc_weights = tf.Variable(tf.truncated_normal(
      [c5_conv_dim * c5_conv_dim * c5_depth, num_hidden], stddev=0.1))
    fc_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    out_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
    out_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

    # Model.
    def model(data):
        print(data.get_shape().as_list())
        conv = tf.nn.conv2d(data, c1_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + c1_biases)
        print(conv.get_shape().as_list())
        pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        print(pooled.get_shape().as_list())
        conv = tf.nn.conv2d(pooled, c3_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + c3_biases)
        pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = pooled.get_shape().as_list()
        print(shape)
        conv = tf.nn.conv2d(pooled, c5_weights, [1, 1, 1, 1], padding='SAME')
        hidden = tf.nn.relu(conv + c5_biases)
        pooled = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
        shape = pooled.get_shape().as_list()
        print(shape)
        reshape = tf.reshape(pooled, [shape[0], shape[1] * shape[2] * shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, fc_weights) + fc_biases)
        return tf.matmul(hidden, out_weights) + out_biases

    # Training computation.
    logits = model(tf_train_dataset)
    loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # Optimizer.
    #optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
    optimizer = tf.train.AdagradOptimizer(0.05).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
